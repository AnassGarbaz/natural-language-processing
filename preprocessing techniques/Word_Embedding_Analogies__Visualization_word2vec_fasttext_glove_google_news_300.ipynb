# %% [markdown]
# ----
#
# Auteurs :
#
# GARBAZ Anass - BOUAYAD Imane
#
# ----

# %% [markdown]
# # Exo 1 :

# %%
sentences = [['this', 'is','an', 'apple'],
             ['I','want','a','glass','of','orange', 'juice'],
             ['I','prefer','strawberies'],
             ['this','ice','cream','is','tasty'],
             ['can','I','have','a','nice','tea','please'],
             ['I','would','like','to','have','a','cup','of','tea']]

# %% [markdown]
# ## Q1 :

# %%
from gensim.models import Word2Vec

# %%
modelwv = Word2Vec(sentences, min_count=1)

# %% [markdown]
# ## Q2 :

# %%
from gensim.models import FastText
model_ft = FastText(sentences, size=100, window=5, min_count=1, workers=4)

# %% [markdown]
# ## Q3 :

# %%
modelwv.wv.save_word2vec_format('modelw.bin')
model_ft.wv.save_word2vec_format('modelft.bin')

# %% [markdown]
# Displaying modelft.bin

# %%
f = open("modelft.bin", "rb")
bytess = f.read() 
print(bytess)
f.close()
# Out:
# b'25 100\nI 0.003913859 0.0047206404 -0.006189348 -0.0026365775 -0.001404387 -0.008139446 -0.0017598908 -0.0054006795 -0.0050145043 0.0020548075 -0.00413659 0.004499389 -0.00044957292 0.0019015009 -0.0040170075 0.0031560406 0.002288062 -0.0023981796 -0.0018332576 0.00021067332 0.0021509961 0.0046192636 -0.001723274 0.0063158725 -0.000719931 0.0046613268 -0.0042517353 -0.006170633 -0.0016026475 0.006475822 -0.003615946 -0.005372603 0.0019294152 -0.0044637662 0.00019704981 -0.002164166 0.0047111567 0.0036686957 -0.005043016 0.0044804327 6.2346924e-05 0.004429961 -0.0040758634 0.0034902466 -0.002899342 -0.0036995092 0.0015889176 -0.001274863 -0.004496108 -0.006305794 -0.0062161456 0.005833055 0.0008093803 -0.0022036298 -0.004566527 -0.0014624309 -0.0024461427 -0.0018458959 0.004245799 0.006645563 -0.0077086575 -0.00062525546 0.00544976 -0.00048257486 -0.002200094 0.003213737 0.005003559 0.0018140215 0.008423094 0.0023434486 0.008480856 -0.0023330618 0.00011709775 0.0040304884 -0.0025792
# ...

# %% [markdown]
# Displaying modelw.bin

# %%
f = open("modelw.bin", "rb")
bytess = f.read() 
print(bytess)
f.close()
# Out:
# b'25 100\nI 0.0019278816 0.0047136936 0.0044430527 -0.0009547972 -0.0016588484 -0.0018649475 -0.0028450633 0.0030712143 -0.004671755 -0.0018640563 -0.0041121803 -0.0016894165 0.0018650092 -0.002849357 0.004354673 -0.0012595147 -0.0030379281 0.0019243966 0.0018559531 0.0029268384 -0.0019295259 -0.00036762175 -0.00029827768 0.00491772 0.0019307616 0.0019825383 0.003953153 -0.001937493 -0.0041505476 0.0039800755 -0.0025118731 -0.0015529855 -0.0035303978 -0.0033794658 0.0037984813 -0.0017621038 -0.003444394 0.0009442975 -0.0006181637 -0.004887454 -0.0026479363 0.00041422513 -0.00057084294 0.0045481967 -0.00304994 -0.0016453221 -0.0016019478 -0.0043905904 0.0044919783 0.0009731885 0.0037081034 0.0040556556 0.0030565502 0.0049395273 -0.0008608018 0.0031444603 0.0013079632 6.39935e-05 -0.0004638693 -0.0031215022 0.0017050648 -0.0028267377 0.0014699623 0.0033815291 0.0035673447 0.000738166 0.0049677473 0.0036784785 -0.00030047924 -0.0047531365 0.0035961326 -0.0045513106 -0.0028919769 0.00192
# ...

# %% [markdown]
# ## Q4 :

# %%
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
def VizualizeEmbeddings(model):
  X = model[model.wv.vocab]
  pca = PCA(n_components=2).fit_transform(X)
  pyplot.scatter(pca[:, 0], pca[:, 1])
  words = list(model.wv.vocab)
  for i, word in enumerate(words):
      pyplot.annotate(word, xy=(pca[i, 0], pca[i, 1]))
  pyplot.show()

# %% [markdown]
# ## Q5 :

# %% [markdown]
# For FastText

# %%
VizualizeEmbeddings(model_ft)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# Word2Vec

# %%
VizualizeEmbeddings(modelwv)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# For FastText we see that the vectors are in the same region, but in word2vec they are more separated

# %% [markdown]
# # EXO 2

# %% [markdown]
# ## Q 1 et 2 :

# %% [markdown]
# Loading Google News vectors

# %%
import gensim.downloader as api

modelggle = api.load('word2vec-google-news-300')
# Out:
# [=====================================-------------] 74.2% 1234.1/1662.8MB downloadedBuffered data was truncated after reaching the output size limit.

# %% [markdown]
# ## Q3 :

# %% [markdown]
# Cat vector

# %%
modelggle['cat']
# Out:
# array([ 0.0123291 ,  0.20410156, -0.28515625,  0.21679688,  0.11816406,
#         0.08300781,  0.04980469, -0.00952148,  0.22070312, -0.12597656,
#         0.08056641, -0.5859375 , -0.00445557, -0.296875  , -0.01312256,
#        -0.08349609,  0.05053711,  0.15136719, -0.44921875, -0.0135498 ,
#         0.21484375, -0.14746094,  0.22460938, -0.125     , -0.09716797,
#         0.24902344, -0.2890625 ,  0.36523438,  0.41210938, -0.0859375 ,
#        -0.07861328, -0.19726562, -0.09082031, -0.14160156, -0.10253906,
#         0.13085938, -0.00346375,  0.07226562,  0.04418945,  0.34570312,
#         0.07470703, -0.11230469,  0.06738281,  0.11230469,  0.01977539,
#        -0.12353516,  0.20996094, -0.07226562, -0.02783203,  0.05541992,
#        -0.33398438,  0.08544922,  0.34375   ,  0.13964844,  0.04931641,
#        -0.13476562,  0.16308594, -0.37304688,  0.39648438,  0.10693359,
#         0.22167969,  0.21289062, -0.08984375,  0.20703125,  0.08935547,
# ...

# %% [markdown]
# ## Q4 :

# %% [markdown]
# ### a )

# %%
res = modelggle.most_similar(positive=['woman', 'king'], negative=['man'])
print(res[0])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# ('queen', 0.7118192911148071)

# %% [markdown]
# ### b )

# %%
res1 = modelggle.most_similar(positive=['Italy', 'Paris'], negative=['France'])
print(res1[0:2])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('Milan', 0.7222140431404114), ('Rome', 0.7028310298919678)]

# %% [markdown]
# ### c )

# %% [markdown]
# #### c - a )

# %%
res = modelggle.most_similar_cosmul(positive=['woman', 'king'], negative=['man'])
print(res[0])
# Out:
# ('queen', 0.9314123392105103)

# %% [markdown]
# #### c - b )

# %%
res = modelggle.most_similar_cosmul(positive=['Italy','Paris'], negative=['France'])
print(res[0:2])
# Out:
# [('Milan', 0.9229924082756042), ('Rome', 0.9071064591407776)]

# %% [markdown]
# # Exo 3 :

# %% [markdown]
# ## Q1 :

# %% [markdown]
# installing Glove

# %%
# !pip install glove-python
# Out:
# ...
#      |████████████████████████████████| 266kB 10.0MB/s
# ...
#   Created wheel for glove-python: filename=glove_python-0.1.0-cp36-cp36m-linux_x86_64.whl size=700299 sha256=ee7b2c9c3914e9f432f0842bcbd1732f78b7b0627f2b13097b1ba27ee30cec59
#   Stored in directory: /root/.cache/pip/wheels/88/4b/6d/10c0d2ad32c9d9d68beec9694a6f0b6e83ab1662a90a089a4b
# Successfully built glove-python
# ...

# %% [markdown]
# importing glove

# %%
from glove import Corpus, Glove

# %% [markdown]
# Creating modelglv of glove :

# %% [markdown]
# ----
# We need first to call the corpus model and fit it on sentences

# %%
corpus_model = Corpus()
corpus_model.fit(sentences, window=10)

# %% [markdown]
# Calling and fitting glove on the corpus model

# %%
modelglv = Glove()#no_components=100, learning_rate=0.05)
modelglv.fit(corpus_model.matrix, epochs=10,
          no_threads=1, verbose=True)
modelglv.add_dictionary(corpus_model.dictionary)
# Out:
# Performing 10 training epochs with 1 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9

# %% [markdown]
# ## Q2 :

# %%
modelglv.most_similar('apple')
# Out:
# [('glass', 0.5146012910031589),
#  ('tea', 0.28297984648268637),
#  ('I', 0.23886838678046776),
#  ('tasty', 0.21705141145687856)]

# %% [markdown]
# ## Q3 :

# %% [markdown]
# Saving the modelglv to 'glove.model'

# %%
modelglv.save('glove.model')

# %% [markdown]
# Converting to word2vec

# %%
from gensim.scripts.glove2word2vec import glove2word2vec

glove2word2vec('glove.model', 'word2vec_output_file')
# Out:
# (43, 5)

# %% [markdown]
# ## Q4 :

# %% [markdown]
# Downloading the zip file

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2020-12-14 21:14:16--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2020-12-14 21:14:16--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2020-12-14 21:14:17--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# ...

# %% [markdown]
# ----
#
# unzip it :

# %%
import zipfile
zip_ref = zipfile.ZipFile('glove.6B.zip', 'r')
zip_ref.extractall('glove6B')
zip_ref.close()

# %% [markdown]
# Preparing the file model to make it easy  to call :

# %%
import gensim
import os
import shutil
import hashlib
from sys import platform

def getFileLineNums(filename):
    f = open(filename, 'r')
    count = 0
    for line in f:
        count += 1
    return count


def prepend_line(infile, outfile, line):
    with open(infile, 'r') as old:
        with open(outfile, 'w') as new:
            new.write(str(line) + "\n")
            shutil.copyfileobj(old, new)

def prepend_slow(infile, outfile, line):
    with open(infile, 'r') as fin:
        with open(outfile, 'w') as fout:
            fout.write(line + "\n")
            for line in fin:
                fout.write(line)

def load(filename):
    num_lines = getFileLineNums(filename)
    gensim_file = 'glove_model.txt'
    gensim_first_line = "{} {}".format(num_lines, 100)
    # Prepends the line.
    prepend_slow(filename, gensim_file, gensim_first_line)
    model = gensim.models.KeyedVectors.load_word2vec_format(gensim_file)
    return model

# %% [markdown]
# Loading the Model :

# %%
modelglv_wiki = load('glove6B/glove.6B.100d.txt')

# %% [markdown]
# ## Q5 :

# %%
modelglv_wiki.most_similar('man')[0:4]
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('woman', 0.832349419593811),
#  ('boy', 0.7914870977401733),
#  ('one', 0.7788748741149902),
#  ('person', 0.7526816129684448)]
